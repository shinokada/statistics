# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
iris = datasets.load_iris()
type(iris)
iris.keys()
type(iris.data)
type(iris.target)
type(iris.target_names)
type(iris.feature_names)
iris.data.shape
iris.target_names
iris.feature_names
iris.filename
# Out:
# sklearn.utils.Bunch
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])
# numpy.ndarray
# numpy.ndarray
# numpy.ndarray
# list
# (150, 4)
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']
# '/Users/shinokada/virtualenvs/jupyter/lib/python3.7/site-packages/sklearn/datasets/data/iris.csv'

# %%
X=iris.data
y = iris.target
df = pd.DataFrame(X, columns=iris.feature_names)
df.head()
df.info()
df.describe()
df.shape
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# dtypes: float64(4)
# memory usage: 4.8 KB
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
# (150, 4)

# %%
_ = pd.plotting.scatter_matrix(df, c = y,figsize=(8,8), marker = 'D')
# _ = pd.plotting.scatter_matrix(df, c = y, figsize=[8,8],x=200, marker = 'D')

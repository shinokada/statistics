# %%
import pandas as pd
import numpy as np
import pdpipe as pdp

# %%
df = pd.read_csv("./Data/USA_Housing.csv")

# %%
round(df.sample(5),2)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3591          50756.17                 5.43                       6.67
# 589           53418.54                 6.33                       8.42
# 1017          64896.62                 5.75                       4.71
# 3055          92774.68                 5.99                       7.16
# 1747          76009.54                 5.64                       6.77
#
#       Avg. Area Number of Bedrooms  Area Population       Price  \
# 3591                          2.43         40714.40   752950.61
# 589                           4.01         33572.75  1250882.29
# 1017                          2.01         33201.08   673225.11
# 3055                          5.38         35016.46  1883469.24
# 1747                          2.36         52832.00  1590804.04
#
#                                                 Address
# 3591  72197 Jesse Freeway Suite 945\nLake Julie, AS ...
# 589                     USS Robinson\nFPO AE 47460-2918
# 1017     4363 Tara Bridge Apt. 728\nRivasfurt, ND 04123
# 3055  97943 Robbins Lodge\nNorth Jessicaborough, FM ...
# 1747   8109 Walter Turnpike\nEast Brenda, PW 06750-8134

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
round(df.describe().T,2)
# Out:
#                                count        mean        std       min  \
# Avg. Area Income              5000.0    68583.11   10657.99  17796.63
# Avg. Area House Age           5000.0        5.98       0.99      2.64
# Avg. Area Number of Rooms     5000.0        6.99       1.01      3.24
# Avg. Area Number of Bedrooms  5000.0        3.98       1.23      2.00
# Area Population               5000.0    36163.52    9925.65    172.61
# Price                         5000.0  1232072.65  353117.63  15938.66
#
#                                     25%         50%         75%         max
# Avg. Area Income               61480.56    68804.29    75783.34   107701.75
# Avg. Area House Age                5.32        5.97        6.65        9.52
# Avg. Area Number of Rooms          6.30        7.00        7.67       10.76
# Avg. Area Number of Bedrooms       3.14        4.05        4.49        6.50
# Area Population                29403.93    36199.41    42861.29    69621.71
# Price                         997577.14  1232669.38  1471210.20  2469065.59

# %%
def size(n):
    if n<=4:
        return 'Small'
    elif 4<n<=6:
        return 'Medium'
    else:
        return 'Big'

df['House_size']=df['Avg. Area Number of Rooms'].apply(size)

# %%
df['House_size']=df['Avg. Area Number of Rooms'].apply(size)

# %%
round(df.sample(5),2)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3803          65718.30                 4.91                       4.15
# 3954          73237.58                 7.18                       6.50
# 4931          77622.96                 6.74                       6.04
# 2074          69753.29                 5.71                       4.88
# 2486          69350.79                 6.91                       8.29
#
#       Avg. Area Number of Bedrooms  Area Population       Price  \
# 3803                          4.14         54798.51   995721.63
# 3954                          2.31         33995.11  1341722.84
# 4931                          3.34         51102.44  1599996.96
# 2074                          2.25         50740.20  1138748.96
# 2486                          4.29         36779.06  1392083.82
#
#                                                 Address House_size
# 3803              410 Benjamin Row\nWest Cody, TN 04841     Medium
# 3954  5160 Anderson Forks Suite 782\nNorth Emily, VA...        Big
# 4931  44268 Michele Square Apt. 984\nCollinsside, WI...        Big
# 2074  510 Erik Track Apt. 093\nPadillastad, MA 37207...     Medium
# 2486                     USNV Cortez\nFPO AE 36896-5919        Big

# %%
drop_age = pdp.ColDrop('Avg. Area House Age')

# %%
df2 = drop_age(df)

# %%
round(df2.sample(5))
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 1076           75302.0                        8.0
# 3159           72848.0                        6.0
# 1796           78160.0                        6.0
# 4990           52724.0                        8.0
# 3557           53970.0                        8.0
#
#       Avg. Area Number of Bedrooms  Area Population      Price  \
# 1076                           4.0          42383.0  1640647.0
# 3159                           3.0          21986.0   960919.0
# 1796                           4.0          31112.0  1264972.0
# 4990                           6.0          14802.0   479501.0
# 3557                           6.0          43352.0  1409943.0
#
#                                                 Address House_size
# 1076  63283 Simmons Meadows Apt. 194\nNorth Amandavi...        Big
# 3159  1552 Michael Village Suite 300\nWest Christoph...        Big
# 1796  3276 Harris Pines Suite 433\nPort Paul, NY 662...        Big
# 4990         86727 Kelly Plaza\nLake Veronica, IL 04474        Big
# 3557  1335 Ariel Mount\nSouth Andreachester, NH 5773...        Big

# %%
pipeline = pdp.ColDrop('Avg. Area House Age')
pipeline+= pdp.OneHotEncode('House_size')

# %%
df3 = pipeline(df)

# %%
round(df3.sample(5))
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 643            86157.0                        6.0
# 2873           57472.0                        7.0
# 1635           63820.0                        6.0
# 2388           67776.0                        8.0
# 4183           52400.0                        9.0
#
#       Avg. Area Number of Bedrooms  Area Population      Price  \
# 643                            2.0          62964.0  1833209.0
# 2873                           5.0          35823.0   998702.0
# 1635                           3.0          28737.0  1049632.0
# 2388                           3.0          38346.0  1101120.0
# 4183                           5.0          18117.0   827268.0
#
#                                                 Address  House_size_Medium  \
# 643     1427 Jennifer Landing\nBlairfurt, TX 86287-9948                  0
# 2873       6984 Guerrero Causeway\nLeeborough, VT 73485                  0
# 1635  948 Jordan Parks Suite 211\nEast Shannonbury, ...                  0
# 2388  8601 Tyler Shore Suite 395\nHoopermouth, OR 94...                  0
# 4183  63242 Brian Gateway Apt. 478\nPeterburgh, NV 8...                  0
#
#       House_size_Small
# 643                  0
# 2873                 0
# 1635                 0
# 2388                 0
# 4183                 0

# %%
def price_tag(x):
    if x>250000:
        return 'keep'
    else:
        return 'drop'

# %%
pipeline = pdp.ColDrop('Avg. Area House Age')
pipeline+= pdp.OneHotEncode('House_size')
pipeline+=pdp.ApplyByCols('Price',price_tag,'Price_tag',drop=False)

# %%
df4 = pipeline(df)

# %%
df4.shape
# Out:
# (5000, 9)

# %%
round(df4.sample(5),2)
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 4245          64608.22                       6.38
# 4933          52848.63                       5.83
# 212           79471.24                       8.20
# 4637          58198.03                       5.60
# 2618          61625.06                       7.46
#
#       Avg. Area Number of Bedrooms  Area Population       Price Price_tag  \
# 4245                          4.43         36947.26   697840.57      keep
# 4933                          4.48         53628.68   880132.84      keep
# 212                           6.21         36616.17  1594415.23      keep
# 4637                          4.40         14226.94   420123.00      keep
# 2618                          3.10         52850.41  1797105.10      keep
#
#                                                 Address  House_size_Medium  \
# 4245                     USNS Taylor\nFPO AE 70099-7063                  0
# 4933  9306 Wright Park Apt. 278\nSouth Jacquelinefor...                  1
# 212   35165 Haley Falls Suite 341\nSouth Elizabeth, ...                  0
# 4637                   Unit 7805 Box 2823\nDPO AE 61896                  1
# 2618      66367 Sandra Oval\nEast Brendaville, NC 08689                  0
#
#       House_size_Small
# 4245                 0
# 4933                 0
# 212                  0
# 4637                 0
# 2618                 0

# %%
pipeline = pdp.ColDrop('Avg. Area House Age')
pipeline+= pdp.OneHotEncode('House_size')
pipeline+=pdp.ApplyByCols('Price',price_tag,'Price_tag',drop=False)
pipeline+=pdp.ValDrop(['drop'],'Price_tag')
pipeline+= pdp.ColDrop('Price_tag')

# %%
df5 = pipeline(df)

# %%
df5.shape
# Out:
# (4990, 8)

# %%
pipeline_scale = pdp.Scale('StandardScaler',exclude_columns=['House_size_Medium','House_size_Small'])

# %%
df6 = pipeline_scale(df5)

# %%
round(df6.sample(5),3)
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 523             -1.332                     -0.577
# 2994             1.270                     -0.391
# 4766            -0.194                     -0.967
# 1834            -1.844                      1.031
# 2630             0.889                      1.408
#
#       Avg. Area Number of Bedrooms  Area Population  Price  \
# 523                         -1.241           -0.268 -1.191
# 2994                        -1.257            1.551  1.854
# 4766                        -0.399            1.412  1.003
# 1834                         0.120            0.010 -1.372
# 2630                        -0.601            2.406  1.857
#
#                                                 Address  House_size_Medium  \
# 523            226 Jennifer Isle\nMillerville, AS 59657                  0
# 2994  5738 Carly Rue Suite 254\nEast Emma, VA 03733-...                  0
# 4766  914 Williamson Isle Apt. 981\nEast Heathershir...                  0
# 1834  0580 Adam Turnpike Suite 906\nWest Steven, MN ...                  0
# 2630           645 Bennett Club\nPort Charles, CA 38269                  0
#
#       House_size_Small
# 523                  0
# 2994                 0
# 4766                 0
# 1834                 0
# 2630                 0

# %%
def extract_state(token):
    return str(token[-2])

pipeline_tokenize=pdp.TokenizeWords('Address')
pipeline_state = pdp.ApplyByCols('Address',extract_state,result_columns='State')
pipeline_state_extract = pipeline_tokenize + pipeline_state
df7 = pipeline_state_extract(df6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-2f7e445752c6> in <module>
#       2     return str(token[-2])
#       3
# ----> 4 pipeline_tokenize=pdp.TokenizeWords('Address')
#       5 pipeline_state = pdp.ApplyByCols('Address',extract_state,result_columns='State')
#       6 pipeline_state_extract = pipeline_tokenize + pipeline_state
#
# AttributeError: module 'pdpipe' has no attribute 'TokenizeWords'

# %%
import pandas as pd; import pdpipe as pdp;

df = pd.DataFrame(
     [[3.2, "Kick the baby!"]], [1], ['freq', 'content'])
tokenize_stage = pdp.TokenizeWords('content')
tokenize_stage(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-accc94b201bc> in <module>
#       1 import pandas as pd; import pdpipe as pdp;
# ----> 2 from nltk.tokenize import word_tokenize
#       3 df = pd.DataFrame(
#       4      [[3.2, "Kick the baby!"]], [1], ['freq', 'content'])
#       5 tokenize_stage = pdp.TokenizeWords('content')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import pandas as pd; 
import pdpipe as pdp;
df = pd.DataFrame([['USA'], ['UK'], ['Greece'],['China']], [1,2,3,4], ['Born'])
df
pdp.OneHotEncode().apply(df)
# Out:
#      Born
# 1     USA
# 2      UK
# 3  Greece
# 4   China
#    Born_Greece  Born_UK  Born_USA
# 1            0        0         1
# 2            0        1         0
# 3            1        0         0
# 4            0        0         0

# %%
import nltk
import sklearn

print('The nltk version is {}.'.format(nltk.__version__))
print('The scikit-learn version is {}.'.format(sklearn.__version__))
